# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("mpg")
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df["origin"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='origin'>

# %%
sns.scatterplot(data=df, x='horsepower', y='mpg')
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
sns.lineplot(data=df, x='horsepower', y='mpg')
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
sns.violinplot(x=df['horsepower'])
# Out:
# <Axes: xlabel='horsepower'>

# %%
df = sns.load_dataset("mpg")
sns.swarmplot(data=df, x="displacement")
# Out:
# <Axes: xlabel='displacement'>

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv(r'C:\Users\Kiyojute\Desktop\Kaggle\EV Data\EV_Population.csv')
df.head()
# Out:
#   State  Model Year       Make Electric Vehicle Type  Electric Range  \
# 0    WA        2020      TESLA                   BEV             266
# 1    WA        2024        BMW                  PHEV              39
# 2    WA        2024        BMW                  PHEV              39
# 3    WA        2018      TESLA                   BEV             215
# 4    WA        2012  CHEVROLET                  PHEV              35
#
#    Base MSRP  Legislative District CAFV Eligibility Simple
# 0          0                  46.0                Eligible
# 1          0                  46.0                Eligible
# 2          0                  43.0                Eligible
# 3          0                   1.0                Eligible
# 4          0                  35.0                Eligible

# %%
df.plot(x='Model Year', y='Electric Range', kind='scatter')
plt.show()
